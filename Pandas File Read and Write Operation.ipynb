# %% [markdown]
# ## File Read and Write Operation

# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=4)

# %%
draft1 = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex1.csv')

# %%
draft1
#type(draft1) type is dataframe
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# read tab seperated file into a dataframe
draft2 = pd.read_table('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/test.tsv')

# %%
draft2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
# reading tab seperated file using pd.read_csv by overriding the seperator argument
draft2 = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/test.tsv', sep = '\t')
draft2
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
# reading a csv file using the pd.read_table by overriding the seperator argument
draft1 = pd.read_table('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex1.csv', sep = ',')
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# making header as None
pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex1.csv', header = None)
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
# reading the csv file and giving custom column name
df = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex2.csv', names = ['col1','col2','col3','col4','col5','col6'])
df
# Out:
#    col1  col2  col3  col4   col5  col6
# 0     1     2     3     4  hello   NaN
# 1     5     6     7     8  world   NaN
# 2     9    10    11    12    foo   NaN

# %% [markdown]
# #### If header is not explicitely defined then the first row is taken as the column names
# #### If header assigned None then there is no column name and the column name takes int values
# #### We can specify custome column name by passing them as an argument

# %%
parsed = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/csv_mindex.csv')
parsed
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
# multi-indexing
parsed = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/csv_mindex.csv', index_col=['key1','key2'])
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex4.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
# in the above output I would like to skip header,the second and third row
result = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex4.csv', skiprows = [0,2,3])
result
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex5.csv')
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
# if we want two columns at a time
result[['a', 'b']] # passing column names as a list
# Out:
#    a   b
# 0  1   2
# 1  5   6
# 2  9  10

# %%
# isnull returns a boolean response
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
# !pip3 install openpyxl
pd.read_excel(r'/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex1.xlsx')
# Out:
# ...
#      |████████████████████████████████| 242 kB 727 kB/s eta 0:00:01
# ...
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
# reading data from a website

url = "https://www.basketball-reference.com/leagues/"

BasketBall_data = pd.read_html(url) # read data from a specified url

BasketBall_data # the data is in list format
# Out:
# [   Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#                 Season                 Lg               Champion
#  0             2021-22                NBA  Golden State Warriors
#  1             2020-21                NBA        Milwaukee Bucks
#  2             2019-20                NBA     Los Angeles Lakers
#  3             2018-19                NBA        Toronto Raptors
#  4             2017-18                NBA  Golden State Warriors
#  ..                ...                ...                    ...
#  80            1950-51                NBA       Rochester Royals
#  81            1949-50                NBA     Minneapolis Lakers
#  82            1948-49                BAA     Minneapolis Lakers
#  83            1947-48                BAA      Baltimore Bullets
#  84            1946-47                BAA  Philadelphia Warriors
#
#         Award Winners                          Top Performers  \
# ...

# %%
df=BasketBall_data[0]
df
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0  \
#                Season                 Lg               Champion
# 0             2021-22                NBA  Golden State Warriors
# 1             2020-21                NBA        Milwaukee Bucks
# 2             2019-20                NBA     Los Angeles Lakers
# 3             2018-19                NBA        Toronto Raptors
# 4             2017-18                NBA  Golden State Warriors
# ..                ...                ...                    ...
# 80            1950-51                NBA       Rochester Royals
# 81            1949-50                NBA     Minneapolis Lakers
# 82            1948-49                BAA     Minneapolis Lakers
# 83            1947-48                BAA      Baltimore Bullets
# 84            1946-47                BAA  Philadelphia Warriors
#
#        Award Winners                          Top Performers  \
#                  MVP Rookie of the Year               Points
# ...

# %%
df.columns # outputs list of all columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',             'Season'),
#             ('Unnamed: 1_level_0',                 'Lg'),
#             ('Unnamed: 2_level_0',           'Champion'),
#             (     'Award Winners',                'MVP'),
#             (     'Award Winners', 'Rookie of the Year'),
#             (    'Top Performers',             'Points'),
#             (    'Top Performers',           'Rebounds'),
#             (    'Top Performers',            'Assists'),
#             (    'Top Performers',         'Win Shares')],
#            )

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %%
df2 = pd.read_html('https://github.com/justmarkham/DAT8/blob/master/data/beer.txt')

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
                 ,sep = ',')

# %%
df4 = pd.read_html('https://github.com/vincentarelbundock/Rdatasets/blob/master/datasets.csv')

# %%
df1
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df2
# Out:
# [     0                                     1
#  0  NaN     name calories sodium alcohol cost
#  1  NaN             Budweiser 144 15 4.7 0.43
#  2  NaN               Schlitz 151 19 4.9 0.43
#  3  NaN             Lowenbrau 157 15 0.9 0.48
#  4  NaN            Kronenbourg 170 7 5.2 0.73
#  5  NaN              Heineken 152 11 5.0 0.77
#  6  NaN         Old_Milwaukee 145 23 4.6 0.28
#  7  NaN            Augsberger 175 24 5.5 0.40
#  8  NaN  Srohs_Bohemian_Style 149 27 4.7 0.42
#  9  NaN            Miller_Lite 99 10 4.3 0.43
#  10 NaN        Budweiser_Light 113 8 3.7 0.40
#  11 NaN                 Coors 140 18 4.6 0.44
#  12 NaN           Coors_Light 102 15 4.1 0.46
#  13 NaN        Michelob_Light 135 11 4.2 0.50
#  14 NaN                 Becks 150 19 4.7 0.76
#  15 NaN                  Kirin 149 6 5.0 0.79
#  16 NaN      Pabst_Extra_Light 68 15 2.3 0.38
#  17 NaN                 Hamms 139 19 4.4 0.43
#  18 NaN   Heilemans_Old_Style 144 24 4.9 0.43
# ...

# %%
df3
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df4
# Out:
# [      Unnamed: 0     Package           Item  \
#  0            NaN         AER        Affairs
#  1            NaN         AER   ArgentinaCPI
#  2            NaN         AER      BankWages
#  3            NaN         AER  BenderlyZwick
#  4            NaN         AER      BondYield
#  ...          ...         ...            ...
#  1879         NaN  wooldridge          wage1
#  1880         NaN  wooldridge          wage2
#  1881         NaN  wooldridge        wagepan
#  1882         NaN  wooldridge        wageprc
#  1883         NaN  wooldridge           wine
#
#                                                    Title  Rows  Cols  n_binary  \
#  0                      Fair's Extramarital Affairs Data   601     9         2
#  1                     Consumer Price Index in Argentina    80     2         0
#  2                                            Bank Wages   474     4         2
#  3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# ...

# %%
df = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex6.csv',nrows = 5)

# %%
df
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %% [markdown]
# * df.head() loads the entire data into memory and then displays the first 10 rows
# * whereas the nrows argument inside  pd.read_csv only loads the specified no.of rows (nrows = 5)

# %%
# data write operation
df = pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex5.csv')
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df.to_csv('dataframe_1.csv')

# %%
df.to_csv('dataframe_2.csv', sep = '\t')

# %%
# removing the index and renaming the columns
df.to_csv('dataframe3.csv', index = False, columns = ['a','b','c','d'])

# %%
dates = pd.date_range('1/1/2022', periods = 10)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(dates)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
ts = pd.Series(np.arange(10), index = dates)
ts
# Out:
# 2022-01-01    0
# 2022-01-02    1
# 2022-01-03    2
# 2022-01-04    3
# 2022-01-05    4
# 2022-01-06    5
# 2022-01-07    6
# 2022-01-08    7
# 2022-01-09    8
# 2022-01-10    9
# Freq: D, dtype: int64

# %%
ts.to_csv('time_series.csv')

# %%
ts = pd.Series(np.arange(3), index = ['Pandas', 'Intro', 'file'])
ts
#type(ts)
# Out:
# Pandas    0
# Intro     1
# file      2
# dtype: int64

# %%
# opening csv file without pandas
import csv
f = open('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex7.csv')
reader = csv.reader(f)
reader

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open ('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex7.csv') as f:
    lines = list(csv.reader(f))
lines
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['1', '2', '3']]

# %%
l1=[1,2,3,4]
l2=[5,6,7,8]
{a:b for a,b in zip(l1,l2)}
# Out:
# {1: 5, 2: 6, 3: 7, 4: 8}

# %% [markdown]
# ### JSON Data

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
type(result)
# Out:
# dict

# %%
asjson = json.dumps(result)
asjson
type(asjson)
# Out:
# str

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name','age','pets'])

# %%
siblings
# Out:
#     name  age                    pets
# 0  Scott   30            [Zeus, Zuko]
# 1  Katie   38  [Sixes, Stache, Cisco]

# %%
data = pd.read_json('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/example.json')
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(data.to_json(orient = 'records'))
# Out:
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# ## Binary Data Format

# %% [markdown]
# * SerDe operation: serialization (object to byte code/write operation) and deserialization (byte code to object/read operation)

# %%
frame =pd.read_csv('/media/mrinal/alex/Pandas_practise/code_pandas1/examples/ex1.csv')
frame
frame.to_pickle('frame_pickle')

# %%
pd.read_pickle('frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# ### Using HDF5 Format

# %%
# !pip3 install tables
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1']= frame
store['obj1_col'] = frame['a']
store
# Out:
# ...
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1_col']
# Out:
# 0     0.760349
# 1     0.793705
# 2    -0.654886
# 3     0.900590
# 4    -0.404518
#         ...
# 95    1.107494
# 96   -1.318433
# 97   -1.152243
# 98   -1.061531
# 99    1.851736
# Name: a, Length: 100, dtype: float64

# %% [markdown]
# ## Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
#data

# %% [markdown]
# * Use jsonviewer to check the json file structure

# %%
data[0]['user']
# Out:
# {'login': 'lolloz98',
#  'id': 48560372,
#  'node_id': 'MDQ6VXNlcjQ4NTYwMzcy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/48560372?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/lolloz98',
#  'html_url': 'https://github.com/lolloz98',
#  'followers_url': 'https://api.github.com/users/lolloz98/followers',
#  'following_url': 'https://api.github.com/users/lolloz98/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/lolloz98/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/lolloz98/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/lolloz98/subscriptions',
#  'organizations_url': 'https://api.github.com/users/lolloz98/orgs',
#  'repos_url': 'https://api.github.com/users/lolloz98/repos',
#  'events_url': 'https://api.github.com/users/lolloz98/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/lolloz98/received_events',
#  'type': 'User',
#  'site_admin': False}
